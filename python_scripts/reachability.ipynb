# %%
import pandas as pd

# %%
df = pd.read_csv("../all_reachability.csv")
df
# Out:
#      Unnamed: 0           website category reachableornot  \
# 0             0     epicgames.com    games            yes
# 1             1         twitch.tv    games             no
# 2             2        roblox.com    games             no
# 3             3  steampowered.com    games            yes
# 4             4            ea.com    games            yes
# ..          ...               ...      ...            ...
# 420        1099     aircanada.com   travel             no
# 421        1100     scitation.org   travel            yes
# 422        1101         sabre.com   travel             no
# 423        1102          turo.com   travel            yes
# 424        1103  fourseasons.com/   travel            yes
#
#                        reason requires_authentication notes
# 0                         NaN                     yes   NaN
# 1         browsernotsupported                     NaN   NaN
# 2    doesnotacceptstdpassword                     NaN   NaN
# ...

# %%
# df.groupby("category").count()

df["website"].shape

df[df["reachableornot"]=="yes"].groupby("category").count()
# Out:
#                 Unnamed: 0  website  reachableornot  reason  \
# category
# entertainment           28       28              28       0
# games                   40       40              40       1
# generalnews             60       60              60       0
# onlineshopping          51       51              51       0
# sports                  28       28              28       0
# travel                  35       35              35       0
#
#                 requires_authentication  notes
# category
# entertainment                        15      0
# games                                39      6
# generalnews                          59      0
# onlineshopping                       22      0
# sports                               14      0
# travel                               35      0
