# %%
import json 
with open("data/byCategoryQ9PP4_copy.json") as f:
    tranco : dict = json.load(f)
    trancoDict : dict[str, list[list]]= tranco 
    # print(tranco.keys())
    key : str
    outDict : dict[str, list[list]]  = {"x" : [[1,"a"]]}

    for key , value  in trancoDict.items(): 
        key = str(key)
        if ("-" in key):
            keys = key.split("-")
            keys = [k.strip() for k in keys]
            print(keys)
            for k in keys:
                outDict.setdefault(k,[]).extend(value)            
        else:
            outDict.setdefault(key,[]).extend(value)
    
    for key, value in outDict.items():
        outDict[key].sort(key=lambda x : x[0])
    with open("data/refiled.json", "w") as f1:
        json.dump(outDict,f1)
# Out:
# ['Streaming Media', 'Media Sharing']
# ['Business', 'Software/Hardware']
# ['Blogs/Wiki', 'Social Networking']
# ['Education/Reference', 'Blogs/Wiki']
# ['Personal Network Storage', 'Interactive Web Applications']
# ['Media Downloads', 'Streaming Media']
# ['Government/Military', 'Health']
# ['Instant Messaging', 'Web Phone']
# ['Streaming Media', 'Professional Networking']
# ['Portal Sites', 'Internet Services']
# ['Finance/Banking', 'General News']
# ['Games', 'Streaming Media']
# ['Shareware/Freeware', 'Software/Hardware']
# ['Personal Pages', 'Internet Services']
# ['Public Information', 'Blogs/Wiki']
# ['Content Server', 'Social Networking']
# ['Content Server', 'Internet Services']
# ['Non', 'Profit/Advocacy/NGO']
# ['Online Shopping', 'Fashion/Beauty']
# ['Streaming Media', 'Content Server']
# ['Remote Access', 'Web Meetings']
# ['Entertainment', 'Blogs/Wiki']
# ['Interactive Web Applications', 'Media Sharing']
# ['Content Server', 'Blogs/Wiki', 'Social Networking']
# ...

# %%
import haralyzer as haralyzer
import csv as csv
import json as json
import os as os
import pandas as pd 
import multiprocessing
import traceback

def harToTimes(aTup):
    harPath = aTup[0]
    harFolder = aTup[1]

    firstParty = harPath.rsplit(".",1)[0]
    # print(firstParty)
    harJson = None
    with open(os.path.join(harFolder,harPath), mode="r") as aHar:
        try : 
            harJson = json.load(aHar)
        except json.JSONDecodeError as e:
            # print(e)
            traceback.print_exc()

    allEntries = harJson["log"]["entries"]
    allEntriesWithRequests = list(filter(lambda anEntry : "request" in anEntry,allEntries))
    thirdPartyEntries = allEntriesWithRequests
    times = []
    for entry in thirdPartyEntries: 
        times.append(entry["startedDateTime"])
    
    return times


harFolder = "../hars_general_news/"
harPathList : list[str] = [harPath for harPath in os.listdir(harFolder) if  os.path.isfile(os.path.join(harFolder,harPath)) ]    


pool = multiprocessing.Pool(14)
harPathList = [(harPath, harFolder) for harPath in harPathList]
resultsDf = pd.DataFrame(columns=["req_times"])
for harLeakList in pool.imap(harToTimes,harPathList):
    for leak in harLeakList:
        resultsDf = pd.concat([resultsDf, pd.DataFrame([leak])],ignore_index=True)
pool.close()

resultsDf.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/chootiya/printing/classes/445_fabian/zarc2/python_scripts/rough.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell:/home/chootiya/printing/classes/445_fabian/zarc2/python_scripts/rough.ipynb#X14sZmlsZQ%3D%3D?line=39'>40</a> for harLeakList in pool.imap(harToTimes,harPathList):
#      <a href='vscode-notebook-cell:/home/chootiya/printing/classes/445_fabian/zarc2/python_scripts/rough.ipynb#X14sZmlsZQ%3D%3D?line=40'>41</a>     for leak in harLeakList:
# ---> <a href='vscode-notebook-cell:/home/chootiya/printing/classes/445_fabian/zarc2/python_scripts/rough.ipynb#X14sZmlsZQ%3D%3D?line=41'>42</a>         resultsDf = pd.concat([resultsDf, pd.DataFrame([leak])],ignore_index=True)
# ...

# %%
import pandas as pd

data = {'A': [1, 2, 3, 4],
        'B': [5, 6, 7, 8],
        'C': [9, 10, 11, 12]}

df = pd.DataFrame(data)

# Get a single row (e.g., row at index 2)
single_row = df.iloc[0:2, 0:2]
print(single_row)

# # Get a single column (e.g., column at index 1)
# single_column = df.iloc[:, 1]
# print(single_column)
# Out:
#    A  B
# 0  1  5
# 1  2  6

# %%
from urllib.parse import unquote
import urllib.parse 
text = "https://analytics.google.com/g/collect?v=2&tid=G-2Q21791Y9D&gtm=45je39d0&_p=1907663423&cid=740723750.1695127806&ul=en-us&sr=2048x1152&uaa=x86&uab=64&uafvl=Chromium%3B116.0.5845.140%7CNot)A%253BBrand%3B24.0.0.0%7CGoogle%2520Chrome%3B116.0.5845.140&uamb=0&uam=&uap=Linux&uapv=6.4.13&uaw=0&_eu=AEA&_s=2&sid=1695127808&sct=1&seg=1&dl=https%3A%2F%2Fuser.gamer.com.tw%2FregS3.php&dr=https%3A%2F%2Fuser.gamer.com.tw%2FregS2.php%3Fm%3Drogernadal322%2540gmail.com%26c%3D83303bf9a385bc6bef9cdb9517c0b28c1695127970&dt=%E6%9C%83%E5%93%A1%E8%A8%BB%E5%86%8A%20-%20%E5%B7%B4%E5%93%88%E5%A7%86%E7%89%B9&en=scroll&ep.service_name=user&epn.percent_scrolled=90&_et=4"
# Out:
# https://analytics.google.com/g/collect?v=2&tid=G-2Q21791Y9D&gtm=45je39d0&_p=1907663423&cid=740723750.1695127806&ul=en-us&sr=2048x1152&uaa=x86&uab=64&uafvl=Chromium;116.0.5845.140|Not)A;Brand;24.0.0.0|Google Chrome;116.0.5845.140&uamb=0&uam=&uap=Linux&uapv=6.4.13&uaw=0&_eu=AEA&_s=2&sid=1695127808&sct=1&seg=1&dl=https://user.gamer.com.tw/regS3.php&dr=https://user.gamer.com.tw/regS2.php?m=rogernadal322@gmail.com&c=83303bf9a385bc6bef9cdb9517c0b28c1695127970&dt=會員註冊 - 巴哈姆特&en=scroll&ep.service_name=user&epn.percent_scrolled=90&_et=4

# %%
with open("./test/theatlantic.com.har") as f: 
    fs = f.read()
found = 0
start = 0
stop =0
regions = []
for i,c in enumerate(fs):
    if (c == '`'):
        found += 1
        if found == 1 : 
            start = i
        elif found == 2:
            stop = i
            regions.append((start,stop))
            found = 0

print(regions)

replacements = []
fslist = list(fs)
for (start,stop) in regions:
    for i in range(start + 1, stop):
        if (fs[start-2] == ':'and fs[start-3] == '"'):
            if fs[i] == '"':
                fslist[i] = ''
            elif fs[i] == "'":
                fslist[i] = ''
            elif fs[i] == "\n":
                fslist[i] = ''
            fslist[start] = '"'
            fslist[stop] = '"'

os = "".join(fslist)

with open("test/out.har","w")as wf:
    print(os, file=wf)
# Out:
# [(3740349, 3741575), (7756034, 7756039), (7756168, 7756171), (7756222, 7756227), (7760574, 7760590), (7843563, 7843574), (7986306, 7986317), (8003729, 8003734), (8003744, 8003753), (8003763, 8003768), (8003794, 8003804), (8055900, 8055905), (8055918, 8055923), (8055929, 8055944), (8055981, 8055997), (8056071, 8056074), (8056087, 8056090), (8056096, 8056111), (8056148, 8056164), (8056237, 8056239), (8056252, 8056254), (8056260, 8056275), (8056324, 8056340), (8056414, 8056417), (8056430, 8056433), (8056439, 8056454), (8056503, 8056519), (8056913, 8056935), (8060040, 8060048), (8069914, 8069923), (8836489, 8837793), (8837801, 8837809), (8839067, 8839623), (8839676, 8841062), (8855551, 8857883), (8883944, 8883954), (8884443, 8887739), (8887784, 8892770), (8893085, 8893093), (8893556, 8893634), (8898550, 8898618), (8898654, 8898691), (8899131, 8899185), (8899222, 8908802), (8911752, 8924159), (8924167, 8924340), (8924868, 8932983), (8932991, 8961446), (8961509, 9270926), (9270942, 9270963
# ...

# %%
aDict = {
    "name": "referer",
    "value": "https://user.gamer.com.tw/regS2.php?m=rogernadal322%40gmail.com&c=83303bf9a385bc6bef9cdb9517c0b28c1695127970"}

for key, value in aDict.items():
    print((key,value))

# %%
vec = [[1,2,3], [4,5,6], [7,8,9]]
print([(num,elem) for elem in vec for num in elem])

# %%
print(unquote(unquote(unquote(text))))

# %%
def findAll(aString :str, subString:str):
    start = 0
    while True: 
        start = aString.find(subString,start)
        if start == -1:
            return
        yield start
        start += len(subString)

print(list(findAll("thisisthefinalcountdown", "zzz")))

# %%
import csv

with open("hars_games/reachability_notes.csv") as f:
    reader = csv.reader(f)
    count = 0
    for row in reader:
        print(row)
        if len(row) != 0 and "yes" in row[1]:
            count += 1
    print(count)
# Out:
# ['site', ' reachable', ' reason', ' confirm account', ' ']
# ['epicgames.com', ' yes', ' NA', '  yes']
# ['twitch.tv', ' no', ' browser not supported', ' NA']
# ['roblox.com', ' no', ' does not accept std password', ' NA']
# ['steampowered.com', ' yes', ' NA', ' yes']
# ['ea.com', ' yes', ' NA', ' yes']
# ['steamcommunity.com', ' no', ' owned by steampowered.com', ' NA']
# ['rayjump.com', ' no', ' chinese', ' NA']
# ['3dmgame.com', ' no', ' chinese', ' NA']
# ['playstation.net', ' no', ' IP not found', ' ']
# ['nintendo.net', ' yes', ' NA', ' yes']
# ['playstation.com', ' yes ']
# ['ali213.net', ' no', ' chinese', ' NA']
# ['chess.com', ' yes', ' NA', ' Yes']
# ['ign.com', ' no', ' under entertainment', ' ']
# ['riotgames.com', ' no', ' data lost feb 26', ' NA']
# ['yayoye-spiele.com', ' no', ' no sign up', ' NA']
# ['huya.com', ' no', ' chinese', ' NA']
# ['gamersky.com', ' no', ' chinese', ' NA']
# ['jagex.com', ' no', ' no sign up', ' no']
# ['xbox.com', ' yes', ' NA', ' ?']
# ...

# %%
import subprocess
import os
import getWebsite    
import json 

hostnames = []
folders = ["../hars_travel/","../hars_entertainment/", "../hars_games/", "../hars_general_news/", "../hars_online_shopping/", "../hars_sports/"]

for folder in folders: 
    print(folder)
    print("[[[[[[[[[[[[[[[[[[]]]]]]]]]]]]]]]]]]")
    for fname in os.listdir(folder):
        if (os.path.isfile(os.path.join(folder,fname))):
            print(fname)
            with open(os.path.join(folder, fname)) as fp:
                try:
                    har = json.load(fp=fp)
                except Exception as e:
                    print(e)
            for page in har["log"]["pages"]:
                print(page["title"])
# Out:
# ../hars_travel/
# [[[[[[[[[[[[[[[[[[]]]]]]]]]]]]]]]]]]
# carrentals.com.har
# http://carrentals.com/
# https://www.carrentals.com/user/createaccount?%20&uurl=e3id%3Dredr%26rurl%3D%2F
# https://www.carrentals.com/user/create-account
# https://www.carrentals.com/carsearch?locn=Los+Angeles%2C+CA%2C+United+States+%28LAX-Los+Angeles+Intl.%29&loc2=Los+Angeles%2C+CA%2C+United+States+%28LAX-Los+Angeles+Intl.%29&vend=&pickupIATACode=LAX&dpln=5783884&returnIATACode=LAX&drid1=5783884&time1=1030AM&time2=1030AM&dagv=1&subm=1&fdrp=0&ttyp=2&acop=2&rdus=10&rdct=1&styp=4
# https://www.carrentals.com/
# booking.com.har
# https://booking.com/
# ...

# %%
import ast
import pandas as pd

def str_to_list(s):
    return ast.literal_eval(s)

#import the findings
df = pd.read_csv("../hars_general_news_cloak.csv", converters={"cloak_list":str_to_list})
df = pd.read_csv("../hars_entertainment_cloak.csv", converters={"cloak_list":str_to_list})
# for csv in ["../hars_entertainment_out.csv", "../hars_online_shopping_out.csv", "../hars_sports_out.csv", "../hars_sports_out.csv", "../hars_games_out.csv", "../hars_travel_out.csv"]: 
#     df = pd.concat([df,pd.read_csv(csv)],ignore_index=True)
    
# for csv in ["../hars_entertainment_out.csv", "../hars_online_shopping_out.csv", "../hars_sports_out.csv", "../hars_sports_out.csv", "../"]
# remove location related leakages 
dropIndex = df[ (df["plain_pii"]=="60201") | (df["plain_pii"]=="Illinois") | (df["plain_pii"]=="Evanston") | (df["third_party"].isna())].index
df.drop(labels=dropIndex,axis=0,inplace=True)
df.reset_index(inplace=True, drop=True)
df.head()
